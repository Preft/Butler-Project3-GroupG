# %% [markdown]
# ## Random Forest Decision Tree
#
# Training Data Score: 0.9597823614739235
#
# Testing Data Score: 0.8959434042614792
#
# MSE:  0.12347079250000448
#
# RMSE:  0.06173539625000224

# %%
# Dependencies
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn import tree
import os
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# import processed data
path = "Trends/"
file = "finalFeatures.csv"
path_file = path + file
df = pd.read_csv(path_file)
df
# Out:
#     Year  Brent ave closing USD  Coffe Export (In 1K 60-kg bags) crop year  \
# 0   1990                  23.76                                      73887
# 1   1991                  20.04                                      79768
# 2   1992                  19.32                                      76957
# 3   1993                  17.01                                      74130
# 4   1994                  15.86                                      65962
# 5   1995                  17.02                                      74253
# 6   1996                  20.64                                      81884
# 7   1997                  19.11                                      77962
# 8   1998                  12.76                                      82872
# 9   1999                  17.90                                      92405
# 10  2000                  28.66                                      87970
# 11  2001                  24.46                                      85759
# 12  2002                  24.99                                      90260
# 13  2003                  28.85                                      87986
# 14  2004                  38.26                                      89841
# 15  2005                  54.57                                      88137
# 16  2006                  65.16                                      98495
# 17  2007                  72.44                                      94173
# 18  2008                  96.94                                      95466
# 19  2009                  61.74                                      94627
# 20  2010                  79.61                                     102962
# 21  2011                 111.26                                     106378
# 22  2012                 111.57                                     107611
# 23  2013                 108.56                                     113519
# 24  2014                  98.97                                     113235
# 25  2015                  53.03                                     120520
# 26  2016                  45.13                                     119502
# 27  2017                  54.71                                     119836
# 28  2018                  71.34                                     125174
#
#     Coffe Imports (In 1K 60-kg bags) Calendar Year 137c  \
# 0                                              100082
# 1                                               97310
# 2                                              103653
# 3                                              101530
# 4                                              100811
# 5                                               95216
# 6                                              103284
# 7                                              108001
# 8                                              109718
# 9                                              116301
# 10                                             119015
# 11                                             122409
# 12                                             126768
# 13                                             128342
# 14                                             136139
# 15                                             136745
# 16                                             142862
# 17                                             149223
# 18                                             154346
# 19                                             151695
# 20                                             161059
# 21                                             165720
# 22                                             170548
# 23                                             176426
# 24                                             105413
# 25                                             108423
# 26                                             112977
# 27                                             118532
# 28                                             121000
#
#     Coffe Produciton (In 1K 60-kg bags) crop year  \
# 0                                           93230
# 1                                          101269
# 2                                           98523
# 3                                           91762
# 4                                           93314
# 5                                           87318
# 6                                          103306
# 7                                           99861
# 8                                          108892
# 9                                          131385
# 10                                         113764
# 11                                         107901
# 12                                         122615
# 13                                         105508
# 14                                         116067
# 15                                         111169
# 16                                         135392
# 17                                         121842
# 18                                         134801
# 19                                         127975
# 20                                         142015
# 21                                         142475
# 22                                         151285
# 23                                         154094
# 24                                         149750
# 25                                         153988
# 26                                         159915
# 27                                         158076
# 28                                         170935
#
#     Domestic Consumption (In 1K 60-kg bags)  ICO composite (USD $/lb)  \
# 0                                     19509                      0.72
# 1                                     20228                      0.67
# 2                                     20951                      0.53
# 3                                     21098                      0.62
# 4                                     21360                      1.34
# 5                                     22603                      1.38
# 6                                     23513                      1.02
# 7                                     24271                      1.34
# 8                                     25117                      1.09
# 9                                     25741                      0.86
# 10                                    27068                      0.64
# 11                                    28309                      0.46
# 12                                    28752                      0.48
# 13                                    29833                      0.52
# 14                                    31413                      0.62
# 15                                    33143                      0.89
# 16                                    34974                      0.96
# 17                                    36911                      1.08
# 18                                    38403                      1.24
# 19                                    39800                      1.16
# 20                                    41858                      1.47
# 21                                    43340                      2.10
# 22                                    44754                      1.56
# 23                                    45509                      1.20
# 24                                    46666                      1.55
# 25                                    47548                      1.25
# 26                                    48488                      1.27
# 27                                    49793                      1.27
# 28                                    50510                      1.09
#
#     Inventories (In 1K 60-kg bags)  \
# 0                            15619
# 1                            13200
# 2                            16843
# 3                            14218
# 4                            12667
# 5                             7905
# 6                             6494
# 7                             6896
# 8                             6601
# 9                             8601
# 10                           12187
# 11                           12678
# 12                           14105
# 13                           13708
# 14                           13259
# 15                           12387
# 16                           13237
# 17                           13696
# 18                           13157
# 19                           12107
# 20                           11274
# 21                           11821
# 22                           12542
# 23                           13791
# 24                           14639
# 25                           15639
# 26                           16745
# 27                           16542
# 28                           15503
#
#     re-exports (In 1K 60-kg bags) Calendar Year 35c  \
# 0                                              8769
# 1                                              9770
# 2                                             10691
# 3                                             11041
# 4                                             12833
# 5                                             11539
# 6                                             12485
# 7                                             14136
# 8                                             15135
# 9                                             15331
# 10                                            16796
# 11                                            18588
# 12                                            19602
# 13                                            21284
# 14                                            21693
# 15                                            24028
# 16                                            26123
# 17                                            28747
# 18                                            32106
# 19                                            31873
# 20                                            34048
# 21                                            35461
# 22                                            36221
# 23                                            36282
# 24                                            39037
# 25                                            40258
# 26                                            42437
# 27                                            43110
# 28                                            44808
#
#     WTI ave closing price USD  retail
# 0                       24.53    4.53
# 1                       21.54    4.48
# 2                       20.58    4.53
# 3                       18.43    4.03
# 4                       17.20    4.59
# 5                       18.43    6.03
# 6                       22.12    5.68
# 7                       20.61    5.35
# 8                       14.42    5.31
# 9                       19.35    4.83
# 10                      30.38    4.19
# 11                      25.98    3.76
# 12                      26.19    3.73
# 13                      31.08    4.24
# 14                      41.51    4.56
# 15                      56.64    4.73
# 16                      66.05    4.89
# 17                      72.34    5.45
# 18                      99.67    6.09
# 19                      61.95    5.72
# 20                      79.48    5.77
# 21                      94.88    6.99
# 22                      94.05    6.91
# 23                      97.98    6.81
# 24                      93.17    6.82
# 25                      48.66    6.02
# 26                      43.29    5.83
# 27                      50.80    6.14
# 28                      65.23    6.38

# %%
df.shape
# Out:
# (29, 11)

# %%
# Optimize data
df = df.drop(columns =['Coffe Imports (In 1K 60-kg bags) Calendar Year 137c',
                  ])
df
# 15                           12387
# 16                           13237
# 17                           13696
# 18                           13157
# 19                           12107
# 20                           11274
# 21                           11821
# 22                           12542
# 23                           13791
# 24                           14639
# 25                           15639
# 26                           16745
# 27                           16542
# 28                           15503
#
#     re-exports (In 1K 60-kg bags) Calendar Year 35c  \
# 0                                              8769
# 1                                              9770
# 2                                             10691
# 3                                             11041
# 4                                             12833
# 5                                             11539
# 6                                             12485
# 7                                             14136
# 8                                             15135
# 9                                             15331
# 10                                            16796
# 11                                            18588
# 12                                            19602
# 13                                            21284
# 14                                            21693
# 15                                            24028
# 16                                            26123
# 17                                            28747
# 18                                            32106
# 19                                            31873
# 20                                            34048
# 21                                            35461
# 22                                            36221
# 23                                            36282
# 24                                            39037
# 25                                            40258
# 26                                            42437
# 27                                            43110
# 28                                            44808
#
#     WTI ave closing price USD  retail
# 0                       24.53    4.53
# 1                       21.54    4.48
# 2                       20.58    4.53
# 3                       18.43    4.03
# 4                       17.20    4.59
# 5                       18.43    6.03
# 6                       22.12    5.68
# 7                       20.61    5.35
# 8                       14.42    5.31
# 9                       19.35    4.83
# 10                      30.38    4.19
# 11                      25.98    3.76
# 12                      26.19    3.73
# 13                      31.08    4.24
# 14                      41.51    4.56
# 15                      56.64    4.73
# 16                      66.05    4.89
# 17                      72.34    5.45
# 18                      99.67    6.09
# 19                      61.95    5.72
# 20                      79.48    5.77
# 21                      94.88    6.99
# 22                      94.05    6.91
# 23                      97.98    6.81
# 24                      93.17    6.82
# 25                      48.66    6.02
# 26                      43.29    5.83
# 27                      50.80    6.14
# 28                      65.23    6.38

# %%
df.shape
# Out:
# (29, 10)

# %%
# Create dataframe for running decision tree
# This was done to upload existing code with similar variables
# Main Data set: data_df

data_df = df.drop("retail", axis=1)
target = df["retail"]
Years = df["Year"]


feature_names = data_df.columns
data_df.head()
# Out:
#    Year  Brent ave closing USD  Coffe Export (In 1K 60-kg bags) crop year  \
# 0  1990                  23.76                                      73887
# 1  1991                  20.04                                      79768
# 2  1992                  19.32                                      76957
# 3  1993                  17.01                                      74130
# 4  1994                  15.86                                      65962
#
#    Coffe Produciton (In 1K 60-kg bags) crop year  \
# 0                                          93230
# 1                                         101269
# 2                                          98523
# 3                                          91762
# 4                                          93314
#
#    Domestic Consumption (In 1K 60-kg bags)  ICO composite (USD $/lb)  \
# 0                                    19509                      0.72
# 1                                    20228                      0.67
# 2                                    20951                      0.53
# 3                                    21098                      0.62
# 4                                    21360                      1.34
#
#    Inventories (In 1K 60-kg bags)  \
# 0                           15619
# 1                           13200
# 2                           16843
# 3                           14218
# 4                           12667
#
#    re-exports (In 1K 60-kg bags) Calendar Year 35c  WTI ave closing price USD
# 0                                             8769                      24.53
# 1                                             9770                      21.54
# 2                                            10691                      20.58
# 3                                            11041                      18.43
# 4                                            12833                      17.20

# %%
# Years

# %%
# Create dataframe for running decision tree
# This was done to upload existing code with similar variables
# Main Data set: data_df

x = df.drop("retail", axis=1)
y = df["retail"]
target = y
data_df = x
print(x.shape)
print(y.shape)
# Out:
# (29, 9)
# (29,)

# %% [markdown]
# Old Code. Should not work past this point with curretn data set.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=42)

# %%
#from sklearn.ensemble import RandomForestRegressor
Econ_model = RandomForestRegressor(n_estimators=200)
Econ_model = Econ_model.fit(X_train, y_train)
Econ_model.score(X_test, y_test)
# Out:
# 0.9121166726142867

# %%
print('Test Acc: %.3f' % Econ_model.score(X_test, y_test))
# Out:
# Test Acc: 0.912

# %%
print(f"Training Data Score: {Econ_model.score(X_train, y_train)}")
print(f"Testing Data Score: {Econ_model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.963249783739242
# Testing Data Score: 0.9121166726142867

# %%
sorted(zip(Econ_model.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.5917473653469192, 'ICO composite (USD $/lb)'),
#  (0.07797326205711498, 'Coffe Produciton (In 1K 60-kg bags) crop year'),
#  (0.06281085448809823, 'Year'),
#  (0.0610491386257965, 'Brent ave closing USD'),
#  (0.06008048029311596, 'Coffe Export (In 1K 60-kg bags) crop year'),
#  (0.046819247214599076, 'Inventories (In 1K 60-kg bags)'),
#  (0.03786274687264892, 're-exports (In 1K 60-kg bags) Calendar Year 35c'),
#  (0.03487719632095673, 'WTI ave closing price USD'),
#  (0.026779708780750443, 'Domestic Consumption (In 1K 60-kg bags)')]

# %%
ypred = Econ_model.predict(X_test)

mse = mean_squared_error(y_test, ypred)
print("MSE: ", mse)
print("RMSE: ", mse*(1/2.0)) 

# Taken from refrence
# Target MSE:  0.130713987032462
# Target RMSE:  0.065356993516231
# Out:
# MSE:  0.10428002187500365
# RMSE:  0.05214001093750183

# %%
print(f"train set shape: {y_test.shape}")
print(f"Test set shape:  {ypred.shape}")
# Out:
# train set shape: (8,)
# Test set shape:  (8,)

# %%
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, linewidth=2, label="original", color ="green")
plt.plot(x_ax, ypred, linewidth=3.0, label="predicted", color = "red")
plt.title("y-test and y-predicted data")
plt.xlabel('X-axis (# Retail data points)')
plt.ylabel('Y-axis (Retail values: USD/lb)')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
 # save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'z1_Economic_model.sav'
joblib.dump(Econ_model, filename)
# Out:
# ['z1_Economic_model.sav']

# %%
y_pred_bs = Econ_model.predict(data_df)

# %%
x_ax = Years
plt.plot(x_ax, target, linewidth=2, label="Original", color ="green")
plt.plot(x_ax, y_pred_bs, linewidth=3.0, label="Predicted", color = "red")
plt.title("Predicted Retail Price-Economic Model")
plt.xlabel('Year from origianl set')
plt.ylabel('Retail values (USD/lb)')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.savefig('Econimic_model.png')
plt.show()
